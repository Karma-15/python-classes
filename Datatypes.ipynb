# %%
# data types

a=10
b="10"
c="word"
d=None
e='word'
f=True
g=False
h=10.5

print(type(a))     # type function: to find the data type of the variable
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))

print(id(a))       #id is a function to find menory location
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'NoneType'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'float'>
# 140704703739288

# %%
# arthematical operators

A=10
B=12
C=A%B
print("The remainder is:",C)
# Out:
# The remainder is: 10

# %%
# assignment operatots

j=10
j+=10
print(j)
# Out:
# 20

# %%
# relational operators

a=10
b=12

print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
print(a<b)
print(a>b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
# logical operators

a=True
b=False

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# AND-
# T AND T =T
# T AND F =F
# F AND T =F
# F AND F =F
#
# OR-
# T OR T =T
# T OR F =T
# F OR T =T
# F OR F =F
#
# NOT-
# NOT T =F
# NOT F =T

# %%
# input function

a=input("enter your name")
print("hello",a)
print(type(a))
# Out:
# hello Karthik
# <class 'str'>

# %%
# typecasting- changing datatype of another datatype

a=int(input("enter a value for a"))
b=int(input("enter a value for a"))
sum=a+b
print("The sum of values entered is:", sum)
# Out:
# The sum of values entered is: 22

# %% [markdown]
# QUESTION- WRITE A PROGRAM TO INPUT SIDE OF A SQUARE AND PRINT ITS AREA
#
# PESUDOCODE-
#
# BEGIN
# WRITE INPUT STATEMENT
# TAKE INPUT AS SIDES OF SQUARE
# CALCULATE AREA
# PRINT AREA
# END

# %%
side = float(input("Enter the side of the square: "))
area = side * side
print("Area of the square is:", area)
# Out:
# Area of the square is: 100.0

# %%
# f string formating

name="sam"
age=25
salary=250000.9999999
print(f"the name is {name} and the age is {age}")
print (f"the salary is: {salary:.3f}")
# Out:
# the name is sam and the age is 25
# the salary is: 250001.000

# %%
# padding 

num=42
print(f"{num:05d}")
# Out:
# 00042

# %%
# alignment 

text="python"
print(f"{text:<10}")  # left alignment
print(f"{text:^10}")  # center alignment
print(f"{text:>10}")  #right alignment

# %%
# string basics

a='this is a srring'
b="this is also a string"
c='''this is also another string'''

# %%
# concatenation

a=7+8
print(a)

a="mango"
b="apple"
d=a+b
c=a+" "+b

print(c)
print(d)
# Out:
# 15
# mango apple
# mangoapple

# %%
# Length - len()

print(len(a))

print()
# Out:
# 5

# %%
# sep and end

print(26,27,28,sep='-')           # seprator

print('hello','world',end="*")    # ending each string
print('loading',end='....')     
print('done')
# Out:
# 26-27-28
# hello world*loading....done

# %%
# escape sequence characters

print('hi this is my \nfirst class')   # \n is referd as next line
print('hi this is my \tfirst class')   # \t is referd as tab space
# Out:
# hi this is my
# first class
# hi this is my 	first class

# %%
# string indexing

name='karthik'
print(name[2])

new='this is a string'
print(new[3])          # positive indexing
print(new[-3])         # negative indexing
# Out:
# r
# s
# i

# %%
# slicing strings - dividing the strings into multiple parts
# string[start:stop:step]

apple="this is a new string"
print(apple[0:6])
print(apple[:])
print(apple[:7])
print(apple[::2])
print(apple[-8:-1])
# Out:
# this i
# this is a new string
# this is
# ti sanwsrn
# w strin
